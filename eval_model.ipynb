# %%
import torch
from torch import nn

# %%
path = 'best_model_optmiSGD_lossCrossEntrop.pth'

# %%
model = torch.load(path)
model
# Out:
# OrderedDict([('conv1.weight',
#               tensor([[[[-1.2134e-03, -2.0410e-03,  2.7562e-02,  ...,  2.0595e-02,
#                           5.3367e-03,  2.1533e-02],
#                         [-2.6475e-03,  4.8498e-03,  1.7253e-02,  ...,  4.1397e-02,
#                           3.8220e-02,  3.6655e-02],
#                         [ 8.4336e-03,  2.5355e-02,  5.7909e-02,  ...,  4.2045e-02,
#                           4.8582e-02,  5.1648e-02],
#                         ...,
#                         [ 1.1707e-03,  4.5648e-02,  3.9903e-03,  ..., -2.8982e-01,
#                          -2.3854e-01, -4.0445e-02],
#                         [-7.1299e-03,  2.5941e-02,  2.1309e-02,  ..., -2.0985e-01,
#                          -1.7033e-01, -1.7463e-02],
#                         [ 4.3333e-03,  3.0823e-02,  5.9361e-02,  ...,  4.4135e-02,
#                           5.3807e-02,  8.4151e-02]],
#
#                        [[ 7.8467e-03, -3.9664e-03,  8.1424e-03,  ..., -2.6050e-02,
# ...
