# %%
import torch
from torch import nn

# %%
path = 'best_model_optmiSGD_lossCrossEntrop.pth'

# %%
model = torch.load(path)
model
# Out:
# OrderedDict([('conv1.weight',
#               tensor([[[[ 5.2994e-04, -3.8993e-04,  2.8582e-02,  ...,  2.2468e-02,
#                           7.5087e-03,  2.3036e-02],
#                         [-3.2810e-04,  6.7449e-03,  1.8712e-02,  ...,  4.3639e-02,
#                           4.0294e-02,  3.8295e-02],
#                         [ 1.1169e-02,  2.7428e-02,  5.9562e-02,  ...,  4.4523e-02,
#                           5.1195e-02,  5.3945e-02],
#                         ...,
#                         [ 2.6635e-03,  4.6222e-02,  4.5557e-03,  ..., -2.8975e-01,
#                          -2.3814e-01, -3.9152e-02],
#                         [-4.7812e-03,  2.6952e-02,  2.1339e-02,  ..., -2.0955e-01,
#                          -1.6976e-01, -1.5931e-02],
#                         [ 6.4852e-03,  3.2479e-02,  6.0298e-02,  ...,  4.4468e-02,
#                           5.4820e-02,  8.6095e-02]],
#
#                        [[ 9.8939e-03, -2.0976e-03,  9.4655e-03,  ..., -2.3953e-02,
# ...
